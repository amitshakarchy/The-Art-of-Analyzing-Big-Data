# %% [markdown]
# <a href="https://colab.research.google.com/github/amitshakarchy/big-data-analysis/blob/main/HW_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework Assignment 4
# ### The Art of Analyzing Big Data - The Data Scientist’s Toolbox

# %% [markdown]
# ## Reddit Networks
# Using the [Reddit networks dataset](http://dynamics.cs.washington.edu/nobackup/reddit/) select the subreddit of your favorite  TV show. Using the data of the selected subreddit,
# answer the following questions:

# %%
# !mkdir datasets
# !mkdir datasets/new_girl
# !wget http://dynamics.cs.washington.edu/nobackup/reddit/NewGirl.tar.gz -O ./datasets/new_girl/NewGirl.tar.gz
# !tar -xf ./datasets/new_girl/NewGirl.tar.gz -C ./datasets/new_girl/
# Out:
# mkdir: cannot create directory ‘datasets’: File exists
# mkdir: cannot create directory ‘datasets/new_girl’: File exists
# --2021-11-16 13:04:24--  http://dynamics.cs.washington.edu/nobackup/reddit/NewGirl.tar.gz
# Resolving dynamics.cs.washington.edu (dynamics.cs.washington.edu)... 128.208.3.120, 2607:4000:200:12::78
# Connecting to dynamics.cs.washington.edu (dynamics.cs.washington.edu)|128.208.3.120|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6948558 (6.6M) [application/x-gzip]
# Saving to: ‘./datasets/new_girl/NewGirl.tar.gz’
#
# ./datasets/new_girl 100%[===================>]   6.63M  9.25MB/s    in 0.7s
#
# 2021-11-16 13:04:25 (9.25 MB/s) - ‘./datasets/new_girl/NewGirl.tar.gz’ saved [6948558/6948558]

# %%
! cat ./datasets/new_girl/metadata.json
# !ls ./datasets/new_girl/
# Out:
# {"start_time": "2011-09-06T13:54:45", "end_time": "2016-10-31T23:09:42", "total_vertices": 4939, "full_graph_key": "/data/timeseries/reddit/NewGirl/NewGirl.2011-09-06.2016-10-31.sgraph", "total_links": 7576, "network_type": "reddit"}metadata.json			      NewGirl.2011-09-06.2014-07-08.sgraph
# NewGirl.2011-09-06.2011-10-04.sgraph  NewGirl.2011-09-06.2014-08-05.sgraph
# NewGirl.2011-09-06.2011-11-01.sgraph  NewGirl.2011-09-06.2014-09-02.sgraph
# NewGirl.2011-09-06.2011-11-29.sgraph  NewGirl.2011-09-06.2014-09-30.sgraph
# NewGirl.2011-09-06.2011-12-27.sgraph  NewGirl.2011-09-06.2014-10-28.sgraph
# NewGirl.2011-09-06.2012-01-24.sgraph  NewGirl.2011-09-06.2014-11-25.sgraph
# NewGirl.2011-09-06.2012-02-21.sgraph  NewGirl.2011-09-06.2014-12-23.sgraph
# NewGirl.2011-09-06.2012-03-20.sgraph  NewGirl.2011-09-06.2015-01-20.sgraph
# NewGirl.2011-09-06.2012-04-17.sgraph  NewGirl.2011-09-06.2015-02-17.sgraph
# NewGirl.2011-09-06.2012-05-15.sgraph  NewGirl.2011-09-06.2015-03-17.sgraph
# NewGirl.2011-09-06.2012-06-12.sgraph  NewGirl.2011-09-06.2015-04-14.sgraph
# NewGirl.2011-09-06.2012-07-10.sgraph  NewGirl.2011-09-06.2015-05-12.sgraph
# NewGirl.2011-09-06.2012-08-07.sgraph  NewGirl.2011-09-06.2015-06-09.sgraph
3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from turicreate) (1.4.1)
# Requirement already satisfied: decorator>=4.0.9 in /usr/local/lib/python3.7/dist-packages (from turicreate) (4.4.2)
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from coremltools==3.3->turicreate) (3.17.3)
# Requirement already satisfied: llvmlite<0.34,>=0.33.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba<0.51.0->turicreate) (0.33.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba<0.51.0->turicreate) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.2->turicreate) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.2->turicreate) (2018.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->turicreate) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->turicreate) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->turicreate) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->turicreate) (3.0.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.1.2)
# Requirement already satisfied: h5py<=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.2.0)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (2.0.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (3.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.37.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.41.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.2.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.12.0)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (2.0.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.13.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.3.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.6.3)
# Collecting python-igraph
#   Downloading python-igraph-0.9.8.tar.gz (9.5 kB)
# Collecting igraph==0.9.8
#   Downloading igraph-0.9.8-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 13.5 MB/s
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: python-igraph
#   Building wheel for python-igraph (setup.py) ... done
#   Created wheel for python-igraph: filename=python_igraph-0.9.8-py3-none-any.whl size=9070 sha256=e520185bee9eef2c0bfea8a66ae708f91ee3543dba4f04d0cfc455c3d9d4aedf
#   Stored in directory: /root/.cache/pip/wheels/15/86/ef/b8bcdfbcb1c489771ad256c7cd1eb4971cdb7f3f670938b798
# Successfully built python-igraph
# Installing collected packages: texttable, igraph, python-igraph
# Successfully installed igraph-0.9.8 python-igraph-0.9.8 texttable-1.6.4

# %%
# import all needed libraries ( for now :) )
import turicreate as tc 
import networkx as nx
import igraph

# %%
# load sgraph using turicreate

sg = tc.load_sgraph("./datasets/new_girl/NewGirl.2011-09-06.2014-07-08.sgraph")
sg.summary()
# Out:
# {'num_edges': 2979, 'num_vertices': 2448}

# %% [markdown]
# **Task 1:** Calculate and visualize the degree distribution  of the vertices  in the network (15pt)

# %%
def sgraph2nxgraph(sgraph, is_directed=True, add_vertices_attributes=True, add_edges_attributes=True):
    if is_directed:
        nx_g = nx.DiGraph()
    else:
        nx_g = nx.Graph()
    if add_vertices_attributes:
        vertices = [(r['__id'] , r) for r in sgraph.vertices]
    else:
        vertices = list(sgraph.get_vertices()['__id'])

    if add_edges_attributes:
        edges = [(r['__src_id'], r['__dst_id'], r) for r in sgraph.edges]
    else:
        edges = [(e['__src_id'], e['__dst_id']) for e in sgraph.get_edges()]
    nx_g.add_nodes_from(vertices)
    nx_g.add_edges_from(edges)
    return nx_g

# %%
ng = sgraph2nxgraph(sg)
print("Networkx: %s" % nx.info(ng))
# Out:
# Networkx: DiGraph with 2448 nodes and 2979 edges

# %%
# Calculate and visualize the degree distribution of the vertices in the network 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

d = ng.degree()
sns.set()
sns.distplot([v for v in dict(d).values()])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Task 2:** Create a subgraph of the top-40 users according to a selected centrality algorithm. Draw the subgraph using circlular layout (15pt)

# %%
# the selected centrality algorithm - degree centrality
deg_cent = nx.degree_centrality(ng)

# %%
# sort deg_cent
sorted_deg = sorted(deg_cent, key=deg_cent.get, reverse=True)[:40]

plt.figure(figsize=(10,10))
h = ng.subgraph(sorted_deg)
nx.draw_circular(h, with_labels=True)

# %%
sorted_deg[:10]
# Out:
# ['Dorkside',
#  'OneOfDozens',
#  'SawRub',
#  'siegel_caww',
#  'drocks27',
#  'The-Beckles',
#  'apostrotastrophe',
#  'knot353',
#  'metalbracelet',
#  'riffleserryday']

amarros': 0, 'MaggiesHarm': 0, 'sidjones182': 0, 'Grave-er': 0, 'eq_ninja': 0, 'guydudeman': 0, 'iwantmykarma': 0, 'hankryan': 0, 'cyainanotherlifebro': 0, 'mattcanyc': 0, 'the_peoples_elbow': 0, 'imamericanok': 0, 'eskalation': 0, 'Sky_Captain117': 0, 'sperryfreak01': 0, 'Dahyno': 0, 'askew1': 0, 'iheartdna': 0, 'SilverFox2222': 0, 'shandelion': 0, 'blueish56': 0, 'penguinbanjo': 0, 'HandicapperGeneral': 0, 'Slammajamma28': 0, 'spontanuous': 0, 'thinkinunicorns': 0, 'bacondev': 0, 'symphonique': 0, 'ailboles': 0, 'mmmbreadsticks': 0, 'CallMeLiam': 0, 'txbelle2014': 0, 'KaseyB': 0, 'dragonkhaleesi': 0, 'kungjaevel': 0, 'rehtulx': 0, 'FeministNewbie': 0, ...

# %%
# average shortest path

averages = dict()
for node in ng.nodes():
   paths = nx.single_source_shortest_path(ng, node)
   num_paths = len(paths)
   agg_length = 0

   for lp in paths.values():
     agg_length += len(lp)

   avg_short_path = agg_length/num_paths
   averages[node] = avg_short_path

print("average shortest path: ", averages)
# Out:
# average shortest path:  {'SirRipo': 1.0, 'Hickspy': 1.0, 'TopesLose': 6.05080831408776, 'blueberrymuffinn': 1.0, 'catstar27': 1.5, 'WhiskeyDuty': 1.0, 'tisharoo': 2.0, 'I_no_longer_lurk': 6.093533487297922, 'bigwillystyle93': 1.0, 'Blerg_ShutItDown': 1.0, 'TheSneakySeal': 5.711316397228638, 'espeo12345': 1.0, 'ours_isthefury': 1.0, 'AtlEm': 8.98729792147806, 'poopyflavouredlolly': 7.210161662817552, 'yeefuckinhaw': 1.0, 'Connguy': 1.0, 'just_call_in_sick': 1.0, 'apercots': 1.0, 'CoriDori': 1.0, 'briteeyez12': 1.0, 'Brain13': 4.92147806004619, 'kayethx': 1.5, 'SepticReVo': 1.0, 'krezmasters': 1.0, 'anjalovesit': 1.0, 'pyrelic': 1.0, 'miles197': 1.0, 'ohshababy': 1.0, 'theHBIC': 1.0, 'DocOTaco': 1.0, 'fluffypandatits': 1.0, 'Disneyprincess95': 1.0, 'ryukaiser': 1.0, 'princess-heya': 1.0, 'syrupriver': 1.0, 'Iwouldlikealongeruse': 1.0, 'hanmarie': 1.0, 'MoreClever': 6.988532110091743, 'CalvinYHobbes': 1.0, 'MyDaddyTaughtMeWell': 5.288683602771362, 'cobweb1989': 2.0, 'birthday-party': 1.5, 'YourBracesHaveHairs': 5.196531791907514, 'TTrui': 8.279768786127168, 'IrishMorphine': 2.6666666666666665, 'FMGUY': 2.0, 'woozlew': 1.0, 'jiminibilibo': 1.0, 'theBirdsofWar': 1.0, 'Versacheese': 1.0, 'OldNickMiller': 1.0, 'tISKA': 6.7398843930635834, 'howboutthatshit': 8.18569780853518, 'psylent': 1.0, 'thejamesstage': 1.0, 'DatCabbage': 1.0, 'think_lambda': 4.92147806004619, 'dwide--schrude': 1.0, 'freedommerc': 5.
# %% [markdown]
# **Task 4:** Use Cytoscape and Gephi to visualize the network, where each vertex size is correlates to its degree (15pt)

# %%
ng = sgraph2nxgraph(sg, False, False, False)
ng.nodes
# Out:
# NodeView(('SirRipo', 'Hickspy', 'TopesLose', 'blueberrymuffinn', 'catstar27', 'WhiskeyDuty', 'tisharoo', 'I_no_longer_lurk', 'bigwillystyle93', 'Blerg_ShutItDown', 'TheSneakySeal', 'espeo12345', 'ours_isthefury', 'AtlEm', 'poopyflavouredlolly', 'yeefuckinhaw', 'Connguy', 'just_call_in_sick', 'apercots', 'CoriDori', 'briteeyez12', 'Brain13', 'kayethx', 'SepticReVo', 'krezmasters', 'anjalovesit', 'pyrelic', 'miles197', 'ohshababy', 'theHBIC', 'DocOTaco', 'fluffypandatits', 'Disneyprincess95', 'ryukaiser', 'princess-heya', 'syrupriver', 'Iwouldlikealongeruse', 'hanmarie', 'MoreClever', 'CalvinYHobbes', 'MyDaddyTaughtMeWell', 'cobweb1989', 'birthday-party', 'YourBracesHaveHairs', 'TTrui', 'IrishMorphine', 'FMGUY', 'woozlew', 'jiminibilibo', 'theBirdsofWar', 'Versacheese', 'OldNickMiller', 'tISKA', 'howboutthatshit', 'psylent', 'thejamesstage', 'DatCabbage', 'think_lambda', 'dwide--schrude', 'freedommerc', 'the_zercher', 'paaulo', 'PhorTheKids', 'DanElHombre', 'fluxuation', 'herrmister', 'k1yle', 'Tubii', 'Footballvike81', '1024ninjas', 'heaupp', 'kevinpilgrim', 'BeenALurkerTooLong', 'samdman', 'blambot', 'deadGOOS3', 'apostrotastrophe', 'Locke_N_Load', 'zancler', 'misswhitnum', 'CanyonJones', 'Annoying_Beast', 'murderball', 'ManWithYourPlan', 'bassoon437', 'NameTak3r', 'iwannagrokwithyou', 'allnutty', 'Kaypas88', 'ladysody', 'TickleMeGio', 'beyron', 'smaxwell90', 'abblesauce', 'kprml', 'rorilium', 'antares07923', 'Gothmaug', 'Dr_Girlfriend_', 'dirk_b', 'GBSii', 'catillack', 'SparkitusRex', 'QuackMcQuack', 'Treblot', 'Amonette2012', 'LadyMadonna', 'whiskeyeyes', 'johnboyboy', 'pupsinthetub', 'Loziraptor', 'irishstereotype', 'heavyblunted', 'hmblm12', 'Dorkside', 'pdoc234', 'DazzlingDuck', 'dassiearwen', 'rivea', 'Chet_Youngblood', 'phyllop23', 'adaminc', 'ajoshw', 'CountZacula', 'Kin-tan-tee', 'lazenbooby', 'SmashingNamePoppet', 'youknowit19', 'drhorriblephd', 'mill3sr', 'SarieldeVergerberg', 'ionlyvoteup', 'pdavda', 'Delahorney', 'KaBoom752', 'Kieo', 'thirdfemme', 'mistielovesyou', 'prime1309', 'cmhooley', 'ltherapistl', 'Noctis_Raptor', 'fish_taco_pirate', 'jcazen', 'Multidisciplinary', 'redeyeddragon', 'manhands101', 'bridget1989', 'Calahagus', 'siaslial', 'foreskinface', 'grandplans', 'M83HUWD', 'TheLastTemplar', 'wearenotscientists', 'Xaphianion', 'misspinaberry', 'flarpy59', 'lakerswiz', 'Link_GR', 'Rob_C', 'andhernamewas_', 'tuckels', 'SirHoneyDip', 'Meeha', 'I-always-win', 'dictatorjim', 'lolhowoldareyou', 'Elliephant91', 'devizkit', 'alimighty1', 'Crumpgazing', 'nymusix', 'Magichamsterorgy', 'ladyplay', 'dimera1', 'jughead776', 'star_particles', 'clever_enough_4_you', 'YouGuysINeverCry', 'adsj', 'microwavedCheetos', 'MGichu', 'shanel3rannan', 'gmb07', 'slimpickis', 'lileyedmonster', 'boomboxB', 'captaincaribou', 'Tamarros', 'MaggiesHarm', 'sidjones182', 'Grave-er', 'eq_ninja', 'guydudeman', 'iwantmykarma', 'hankryan', 'cyainanotherlifebro', 'mattcanyc', 'the_peoples_elbow', 'imamericanok', 'eskalation', 'Sky_Captain117', 'sperryfreak01', 'Dahyno', 'askew1', 'iheartdna', 'SilverFox2222', 'shandelion', 'blueish56', 'penguinbanjo', 'HandicapperGeneral', 'Slammajamma28', 'spontanuous', 'thinkinunicorns', 'bacondev', 'symphonique', 'ailboles', 'mmmbreadsticks', 'CallMeLiam', 'txbelle2014', 'KaseyB', 'dragonkhaleesi', 'kungjaevel', 'rehtulx', 'FeministNewbie', 'Ser_Penrose', 'stefXXrae', 'Rumbleroar_', 'Skater_Bruski', 'tedtutors', 'JK07', 'FrostyPoot', 'yyz_xyu', 'KeepJerseyDirty', 'Brillliant', 'fluffy324', 'themustardtiger', 'LeKetay2525', 'Itseemedfunny', 'kaywhy88', 'oohmoonbeams', 'DarthCthulu', 'chucho_0', 'okam97', 'Chadadarsya', 'thisisatribute', 'bigmikebrennan', 'Lemaya', 'ham_rod', 'ashowofhands', 'Breezy9401', 'WagnerLov3', 'iwillattack', 'brobro757', 'ketchumkilpat', 'Salzberger', 'AK409', 't4nt4lus', 'BasherTarr', 'bilingualgiraffe', 'makingbacon', 'Jamer70', 'longsnapper', 'forsan_et_haec', '_tweaks', 'GlucoseGlucose', 'mulark13', 'YoloSwagBiscuits', 'CrashRiot', 'poopydoop', 'mynameisDJ2006', 'icuhalloffame', 'M ...

# %%
H = nx.relabel_nodes(ng, lambda x: x.replace("_", " "))
H

# %%
# save gml

nx.write_gml(H, "./datasets/new_girl.gml")

# %% [markdown]
# ![new_girl (4).gml.png](data:image/png;base64,...)

# %% [markdown]
# **Task 5:** Write a function that for a given vertex creates a subgraph of the selected vertex and all the vertex's in/out friends (10pt).
# Draw the subgraph (5pt). Calculate the number of verticies and edges in the subgraph (5pt)

# %%
from networkx.algorithms.community import greedy_modularity_communities
from networkx.algorithms.community.centrality import girvan_newman

# %%
def vertex_subgraph(node):
    neighbors = ng.neighbors(node)
    sub = ng.subgraph(neighbors)
    return sub


sub = vertex_subgraph("Dorkside")

print(f"#edges : {sub.number_of_edges()}")
# drawing
plt.figure(figsize=(10,10))
nx.draw_kamada_kawai(sub, with_labels=True)
# Out:
# #edges : 159

# %% [markdown]
# **Task 6:** Find the top-10 most centeral players at [The Free Internet Chess Sever](http://dynamics.cs.washington.edu/nobackup/chess/fcis.tar.gz) (15 pt). Visualize part of the network (5pt).
#
# **Note:** The network has 429,747,476 edges

# %%
# !mkdir datasets
# !mkdir datasets/freechess
# !wget http://dynamics.cs.washington.edu/nobackup/chess/fcis.tar.gz -O ./datasets/freechess/freechess.tar.gz
# !tar -xf ./datasets/freechess/freechess.tar.gz -C ./datasets/freechess/
# Out:
# --2021-11-16 18:18:49--  http://dynamics.cs.washington.edu/nobackup/chess/fcis.tar.gz
# Resolving dynamics.cs.washington.edu (dynamics.cs.washington.edu)... 128.208.3.120, 2607:4000:200:12::78
# Connecting to dynamics.cs.washington.edu (dynamics.cs.washington.edu)|128.208.3.120|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6852261483 (6.4G) [application/x-gzip]
# Saving to: ‘./datasets/freechess/freechess.tar.gz’
#
# ./datasets/freeches 100%[===================>]   6.38G  14.7MB/s    in 8m 3s
#
# 2021-11-16 18:26:52 (13.5 MB/s) - ‘./datasets/freechess/freechess.tar.gz’ saved [6852261483/6852261483]
#
# ^C

# %%
# !ls datasets/freechess
# Out:
# FCIS  freechess.tar.gz

# %%
! pip install turicreate
# Out:
# Collecting turicreate
#   Downloading turicreate-6.4.1-cp37-cp37m-manylinux1_x86_64.whl (92.0 MB)
#      |████████████████████████████████| 92.0 MB 4.8 kB/s
# Collecting numba<0.51.0
#   Downloading numba-0.50.1-cp37-cp37m-manylinux2014_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 48.0 MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from turicreate) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from turicreate) (1.15.0)
# Collecting resampy==0.2.1
#   Downloading resampy-0.2.1.tar.gz (322 kB)
#      |████████████████████████████████| 322 kB 74.0 MB/s
# Requirement already satisfied: pandas>=0.23.2 in /usr/local/lib/python3.7/dist-packages (from turicreate) (1.1.5)
# Collecting tensorflow<2.1.0,>=2.0.0
#   Downloading tensorflow-2.0.4-cp37-cp37m-manylinux2010_x86_64.whl (86.4 MB)
#      |████████████████████████████████| 86.4 MB 22 kB/s
# Collecting coremltools==3.3
#   Downloading coremltools-3.3-cp37-none-manylinux1_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 57.2 MB/s
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.7/dist-packages (from turicreate) (2.23.0)
# Requirement already satisfied: decorator>=4.0.9 in /usr/local/lib/python3.7/dist-packages (from turicreate) (4.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from turicreate) (1.19.5)
# Collecting prettytable==0.7.2
#   Downloading prettytable-0.7.2.zip (28 kB)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from turicreate) (7.1.2)
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from coremltools==3.3->turicreate) (3.17.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba<0.51.0->turicreate) (57.4.0)
# Collecting llvmlite<0.34,>=0.33.0.dev0
#   Downloading llvmlite-0.33.0-cp37-cp37m-manylinux1_x86_64.whl (18.3 MB)
#      |████████████████████████████████| 18.3 MB 61 kB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.2->turicreate) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.2->turicreate) (2.8.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->turicreate) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->turicreate) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->turicreate) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.9.1->turicreate) (3.0.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.2.0)
# Collecting h5py<=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 33.4 MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.37.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.41.1)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.5 MB/s
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading tensorboard-2.0.2-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 44.4 MB/s
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449 kB)
#      |████████████████████████████████| 449 kB 65.4 MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.8.1)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.13.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (3.3.0)
# Collecting numpy
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 102.9 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.6.0)
# Building wheels for collected packages: prettytable, resampy, gast
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=fb44ac98fbee71ded3affda476746b95c5060f2bf8ca0ee6272afcfe0f587cd4
#   Stored in directory: /root/.cache/pip/wheels/b2/7f/f6/f180315b584f00445045ff1699b550fa895d09471337ce21c6
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.1-py3-none-any.whl size=320860 sha256=8f0eb12e38d1ad4b9b95f5e48ec10f452f75dc1f9adb403fee90f71beede69f1
#   Stored in directory: /root/.cache/pip/wheels/71/74/53/d5ceb7c5ee7a168c7d106041863e71ac3273f4a4677743a284
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=cc28f81d4180ab657b38648ff42b4413068c191a1c66c6799a006ac0d9e0f78c
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built prettytable resampy gast
# Installing collected packages: numpy, llvmlite, h5py, tensorflow-estimator, tensorboard, numba, keras-applications, gast, tensorflow, resampy, prettytable, coremltools, turicreate
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
#   Attempting uninstall: resampy
#     Found existing installation: resampy 0.2.2
#     Uninstalling resampy-0.2.2:
#       Successfully uninstalled resampy-0.2.2
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 2.4.0
#     Uninstalling prettytable-2.4.0:
#       Successfully uninstalled prettytable-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.14.1 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# librosa 0.8.1 requires resampy>=0.2.2, but you have resampy 0.2.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed coremltools-3.3 gast-0.2.2 h5py-2.10.0 keras-applications-1.0.8 llvmlite-0.33.0 numba-0.50.1 numpy-1.18.5 prettytable-0.7.2 resampy-0.2.1 tensorboard-2.0.2 tensorflow-2.0.4 tensorflow-estimator-2.0.1 turicreate-6.4.1

# %%
import turicreate as tc
sf_edges = tc.SFrame.read_csv("./datasets/freechess/FCIS/fcis_chess.interactions.csv", nrows= 100000)
sf_vertices = tc.SFrame.read_csv("./datasets/freechess/FCIS/fcis_chess.vertices.csv", nrows= 100000)
# Out:
# Finished parsing file /content/datasets/freechess/FCIS/fcis_chess.interactions.csv
# Parsing completed. Parsed 100 lines in 4.33116 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /content/datasets/freechess/FCIS/fcis_chess.interactions.csv
# Parsing completed. Parsed 100000 lines in 1.14892 secs.
# Finished parsing file /content/datasets/freechess/FCIS/fcis_chess.vertices.csv
# Parsing completed. Parsed 100 lines in 1.51823 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /content/datasets/freechess/FCIS/fcis_chess.vertices.csv
# Parsing completed. Parsed 100000 lines in 0.487203 secs.

# %%
sg_fcis = tc.SGraph(vertices=sf_vertices, edges=sf_edges,
                    vid_field="v_id", src_field="src_id", dst_field="dst_id")
sg_fcis.summary()
# Out:
# {'num_edges': 100000, 'num_vertices': 100000}

# %%
ng = sgraph2nxgraph(sg_fcis,False,False,False)
d = nx.degree_centrality(ng)
d
# Out:
# {'nedra': 0.0,
#  'Jocki': 0.0,
#  'eide': 0.0,
#  'bigoak': 0.0,
#  'eriskigal': 0.0,
#  'patricbateman': 0.0,
#  'franckthobie': 0.0,
#  'xjester': 0.0,
#  'rcells': 0.0,
#  'Sveniska': 0.0,
#  'galadrim': 0.0,
#  'vonFallersleben': 0.0,
#  'blitzoff': 0.0,
#  'TRACTORTRAILER': 0.0,
#  'Luckstone': 0.0,
#  'Beginnersmind': 0.0,
#  'Chezzyplayer': 0.0,
#  'RandomTrend': 0.0,
#  'buffysexslave': 0.0,
#  'BigDragon': 0.0,
#  'Alisdair': 0.0,
#  'repeteraupprepa': 0.0,
#  'Growler': 0.0,
#  'pml': 0.0,
#  'BelgiumFreak': 0.0,
#  'imdoener': 0.0,
#  'Spero': 0.0,
#  'kcase': 0.0,
#  'pmmal': 0.0,
#  'kayakguide': 0.0,
#  'GimmieAHug': 0.0,
#  'mbialecki': 0.0,
#  'StangIsBack': 0.0,
#  'rasa': 0.0,
#  'MrBlunderful': 0.0,
#  'SuD': 0.0,
#  'Kuikie': 0.0,
#  'sadsacker': 0.0,
#  'LuigiBot': 0.0,
#  'nitsuaj': 0.0,
#  'gwc': 0.0,
#  'richardscillath': 0.0,
#  'Ferdz': 0.0,
#  'Moskvich': 0.0,
#  'flycheese': 0.0,
#  'mersecske': 0.0,
#  'schupp': 0.0,
#  'nimzovic': 0.0,
#  'Pcfaj': 0.0,
#  'cobblet': 0.0,
#  'BischoffPremium': 0.0,
#  'Abe': 0.0,
#  'moomooben': 0.0,
#  'raap': 0.0,
#  'Pappnas': 0.0,
#  'DafLeSauvageon': 0.0,
#  'duedipicche': 0.0,
#  'cuplawierdos': 0.0,
#  'RavenousBird': 0.0,
#  'runforlife': 0.0,
#  'CoolMad': 0.0,
#  'ORHIDEEA': 0.0,
#  'AndreyfromMoscow': 0.0,
#  'Babich': 0.0,
#  'Anticristo': 0.0,
#  'julillo': 0.0,
#  'aeava': 0.0,
#  'MoxRuby': 0.0,
#  'jerkface': 0.0,
#  'StarOfFICS': 0.0,
#  'MikeMannx': 0.0,
#  'Cebah': 0.0,
#  'dalbini': 0.0,
#  'Nahsje': 0.0,
#  'nodakindy': 0.0,
#  'wilyxcoyote': 0.0,
#  'Mleko': 0.0,
#  'CDH': 0.0,
#  'kkatcumac': 0.0,
#  'sredds': 0.0,
#  'playerhater': 0.0,
#  'colbertuk': 0.0,
#  'Dostoievski': 0.0,
#  'meight': 0.0,
#  'bookworm': 0.0,
#  'kampman': 0.0,
#  'karlzen': 0.0,
#  'Chezz': 0.0,
#  'kunegis': 0.0,
#  'Virtus': 0.0,
#  'maradonas': 0.0,
#  'DrunkenNun': 0.0,
#  'Emiliano': 0.0,
#  'xereos': 0.0,
#  'ronaldoooo': 0.0,
#  'barlog': 0.0,
#  'momurda': 0.0,
#  'Cuno': 0.0,
#  'disturbedone': 0.0,
#  'ffbt': 0.0,
#  'darkroast': 0.0,
#  'saibot': 0.0,
#  'modom': 0.0,
#  'mesj': 0.0,
#  'eyeofthewolf': 0.0,
#  'ridla': 0.0,
#  'alnilam': 0.0,
#  'BGHAWKSTA': 0.0,
#  'matsch': 0.0,
#  'ViperDC': 0.0,
#  'HiLFE': 0.0,
#  'oemen': 0.0,
#  'bluthunder': 0.0,
#  'bishopsdemise': 0.0,
#  'GerryScott': 0.0,
#  'ThorpeCloud': 0.0,
#  'heartland': 0.0,
#  'NeedForChess': 0.0,
#  'tegon': 0.0,
#  'perola': 0.0,
#  'aperfectcircle': 0.0,
#  'postmaster': 0.0,
#  'JSIM': 0.0,
#  'touko': 0.0,
#  'VVVV': 0.0,
#  'bhudgeons': 0.0,
#  'BManNC': 0.0,
#  'kiwiboy': 0.0,
#  'adpi': 0.0,
#  'igriseum': 0.0,
#  'aldobrando': 0.0,
#  'AlaEsGrande': 0.0,
#  'PsygNosis': 0.0,
#  'Aphanasius': 0.0,
#  'sdmafia': 0.0,
#  'Mindhunter': 0.0,
#  'Asoku': 0.0,
#  'Hiroe': 0.0,
#  'ericbrunson': 0.0,
#  'HowHard': 0.0,
#  'sharman': 0.0,
#  'Chadarev': 0.0,
#  'skafis': 0.0,
#  'MilleniumJoe': 0.0,
#  'gonza': 0.0,
#  'DrRitchie': 0.0,
#  'uchman': 0.0,
#  'melocoton': 0.0,
#  'scorpyo': 0.0,
#  'hogus': 0.0,
#  'temerario': 0.0,
#  'rubifis': 0.0,
#  'EricHK': 0.0,
#  'KillerAngel': 0.0,
#  'liquidtension': 0.0,
#  'rtyu': 0.0,
#  'ecarratala': 0.0,
#  'hmckayau': 0.0,
#  'marwanag': 0.0,
#  'Vickerym': 0.0,
#  'Wiggin': 0.0,
#  'Jartrond': 0.0,
#  'cuiltje': 0.0,
#  'aditza': 0.0,
#  'klion': 0.0,
#  'Cruin': 0.0,
#  'Travinator': 0.0,
#  'mathmagician': 0.0,
#  'IsegrimWolf': 0.0,
#  'gibas': 0.0,
#  'IkPaysBas': 0.0,
#  'Hanta': 0.0,
#  'dlitvin': 0.0,
#  'ajeeba': 0.0,
#  'roqui': 0.0,
#  'engineart': 0.0,
#  'ohkeepa': 0.0,
#  'credmp': 0.0,
#  'contain': 0.0,
#  'Lightchess': 0.0,
#  'BAugustus': 0.0,
#  'therocker': 0.0,
#  'funkycat': 0.0,
#  'JimmyS': 0.0,
#  'Arminist': 0.0,
#  'sixtyfoursquares': 0.0,
#  'houstonhottie': 0.0,
#  'hnrmata': 0.0,
#  'ideaweb': 0.0,
#  'DJCarlo': 0.0,
#  'Dikiy': 0.0,
#  'gipodiablo': 0.0,
#  'xbO': 0.0,
#  'Botchy': 0.0,
#  'roadrashe': 0.0,
#  'tauro': 0.0,
#  'ckurtis': 0.0,
#  'Elephants': 0.0,
#  'GoranL': 0.0,
#  'Usama': 0.0,
#  'dge': 0.0,
#  'Nicobel': 0.0,
#  'vsb': 0.0,
#  'parvenu': 0.0,
#  'THECHANAKYA': 0.0,
#  'subheat': 0.0,
#  'SHD': 0.0,
#  'Microbe': 0.0,
#  'SSJCrono': 0.0,
#  'colie': 0.0,
#  'bjarnst': 0.0,
#  'gigimina': 0.0,
#  'bongars': 0.0,
#  'kopr': 0.0,
#  'belvadare': 0.0,
#  'lgslgs': 0.0,
#  'ostrovski': 0.0,
#  'hermoniemaster': 0.0,
#  'Pijpenla': 0.0,
#  'Radon': 0.0,
#  'pltxtra': 0.0,
#  'Fredolor': 0.0,
#  'ruhatron': 0.0,
#  'rimjaw': 0.0,
#  'scimi': 0.0,
#  'Mykeyjoe': 0.0,
#  'shimmer': 0.0,
#  'MarkSh': 0.0,
#  'ajaaja': 0.0,
#  'Roscovite': 0.0,
#  'KungPowYou': 0.0,
#  'EdgardV': 0.0,
#  'chessabc': 0.0,
#  'fgg': 0.0,
#  'Thinkandmove': 0.0,
#  'Sandwych': 0.0,
#  'LordFarquad': 0.0,
#  'rbriand': 0.0,
#  'majoros': 0.0,
#  'rodeloper': 0.0,
#  'mayerwu': 0.0,
#  'SpeTIX': 0.0,
#  'LordGruk': 0.0,
#  'dagfinbr': 0.0,
#  'detje': 0.0,
#  'Exonox': 0.0,
#  'soulbrother': 0.0,
#  'Mical': 0.0,
#  'kaush': 0.0,
#  'Cernienko': 0.0,
#  'tondim': 0.0,
#  'Bluecap': 0.0,
#  'Voona': 0.0,
#  'fourmate': 0.0,
#  'bvb': 0.0,
#  'loraine': 0.0,
#  'AftBurn': 0.0,
#  'dumdumdum': 0.0,
#  'pyannul': 0.0,
#  'nAs': 0.0,
#  'AudioAfreak': 0.0,
#  'agalan': 0.0,
#  'twemp': 0.0,
#  'chrikru': 0.0,
#  'Zricky': 0.0,
#  'EParent': 0.0,
#  'snkain': 0.0,
#  'THEcooldude': 0.0,
#  'wurble': 0.0,
#  'smitE': 0.0,
#  'TallumusPaulumus': 0.0,
#  'kyfi': 0.0,
#  'Esopton': 0.0,
#  'Gnomcheto': 0.0,
#  'slottved': 0.0,
#  'Fagatello': 0.0,
#  'scapes': 0.0,
#  'jimshi': 0.0,
#  'nettermann': 0.0,
#  'SMACKDOWN': 0.0,
#  'Kadin': 0.0,
#  'MessiahK': 0.0,
#  'BadBoyofChess': 0.0,
#  'bandersnatch': 0.0,
#  'maronti': 0.0,
#  'SiKsikSIK': 0.0,
#  'Kandiskj': 0.0,
#  'rupi': 0.0,
#  'sloppyplayer': 0.0,
#  'kepka': 0.0,
#  'Breanna': 0.0,
#  'yamutha': 0.0,
#  'suid': 0.0,
#  'Fox': 0.0,
#  'Sign': 0.0,
#  'bugo': 0.0,
#  'abuna': 0.0,
#  'Chofy': 0.0,
#  'ArithmeticMean': 0.0,
#  'praud': 0.0,
#  'tiburcio': 0.0,
#  'tdhep': 0.0,
#  'MilanoComp': 0.0,
#  'sridhar': 0.0,
#  'HumanProg': 0.0,
#  'molus': 0.0,
#  'SSmander': 0.0,
#  'mikhailchess': 0.0,
#  'jsit': 0.0,
#  'SteveW': 0.0,
#  'speedboy': 0.0,
#  'borussia': 0.0,
#  'Craigbarrett': 0.0,
#  'andyscurls': 0.0,
#  'ArmoredKnight': 0.0,
#  'Kevbon': 0.0,
#  'TheGenious': 0.0,
#  'Kaczka': 0.0,
#  'thechessinator': 0.0,
#  'DNAsis': 0.0,
#  'oOOH': 0.0,
#  'reymond': 0.0,
#  'hellors': 0.0,
#  'cIoJo': 0.0,
#  'BlindTord': 0.0,
#  'Mistu': 0.0,
#  'Eddulf': 0.0,
#  'garri': 0.0,
#  'nicoletta': 0.0,
#  'abpz': 0.0,
#  'Pratick': 0.0,
#  'ilf': 0.0,
#  'Cuckoo': 0.0,
#  'TheShrek': 0.0,
#  'Weiner': 0.0,
#  'ILLBA': 0.0,
#  'qwestux': 0.0,
#  'KMANTAMPA': 0.0,
#  'Vlastimil': 0.0,
#  'Disruptor': 0.0,
#  'AnnointedOne': 0.0,
#  'surlybrit': 0.0,
#  'thoughtinvasion': 0.0,
#  'camandokewlguy': 0.0,
#  'dlrcop': 0.0,
#  'Aboul': 0.0,
#  'pablopena': 0.0,
#  'huascarelinca': 0.0,
#  'gerhmartin': 0.0,
#  'DeporFAN': 0.0,
#  'phillyeagles': 0.0,
#  'HertogvanGelre': 0.0,
#  'bearpaw': 0.0,
#  'eldaristari': 0.0,
#  'okkeg': 0.0,
#  'AdirondackMan': 0.0,
#  'juicy': 0.0,
#  'kusudama': 0.0,
#  'badday': 0.0,
#  'INT': 0.0,
#  'Ithran': 0.0,
#  'skyfire': 0.0,
#  'Cheerio': 0.0,
#  'cdog': 0.0,
#  'hendryjh': 0.0,
#  'vinesh': 0.0,
#  'CassRep': 0.0,
#  'fritsblasel': 0.0,
#  'ogman': 0.0,
#  'baabs': 0.0,
#  'xmr': 0.0,
#  'royke': 0.0,
#  'Owyn': 0.0,
#  'tobey': 0.0,
#  'daq': 0.0,
#  'MHeinen': 0.0,
#  'chenm': 0.0,
#  'Wickerdywack': 0.0,
#  'brunok': 0.0,
#  'sozinsky': 0.0,
#  'argud': 0.0,
#  'Koyanistazi': 0.0,
#  'inculcation': 0.0,
#  'Xlance': 0.0,
#  'GunFighter': 0.0,
#  'dabdon': 0.0,
#  'schaapman': 0.0,
#  'MHOJAI': 0.0,
#  'chesscpm': 0.0,
#  'Obliterous': 0.0,
#  'jpferriz': 0.0,
#  'EyesOfBlue': 0.0,
#  'mizzike': 0.0,
#  'Limpet': 0.0,
#  'Craigasf': 0.0,
#  'boccio': 0.0,
#  'LonewolfLunatic': 0.0,
#  'Seehund': 0.0,
#  'michaeldeverdierr': 0.0,
#  'extrao': 0.0,
#  'ganisha': 0.0,
#  'Cava': 0.0,
#  'Vungell': 0.0,
#  'nieder': 0.0,
#  'Backhaus': 0.0,
#  'romaz': 0.0,
#  'agenttesta': 0.0,
#  'gavgcool': 0.0,
#  'DriftingWoods': 0.0,
#  'parusree': 0.0,
#  'willewalle': 0.0,
#  'ioc': 0.0,
#  'Velasca': 0.0,
#  'Tharmat': 0.0,
#  'Stoikan': 0.0,
#  'BrokenWill': 0.0,
#  'apocalypseman': 0.0,
#  'ficsgarde': 0.0,
#  'metfab': 0.0,
#  'Kumla': 0.0,
#  'JobWyoming': 0.0,
#  'chcblch': 0.0,
#  'rwgreen': 0.0,
#  'pcoppens': 0.0,
#  'crashke': 0.0,
#  'jurdieff': 0.0,
#  'Adonika': 0.0,
#  'ABCMan': 0.0,
#  'nishtish': 0.0,
#  'JoseRaoul': 0.0,
#  'Achillis': 0.0,
#  'meremo': 0.0,
#  'Sithaer': 0.0,
#  'wwp': 0.0,
#  'jeypee': 0.0,
#  'RumorHasIt': 0.0,
#  'suckmywhiteass': 0.0,
#  'Jafir': 0.0,
#  'aslkrao': 0.0,
#  'curlyq': 0.0,
#  'corvino': 0.0,
#  'Kull': 0.0,
#  'muskelmann': 0.0,
#  'bscotts': 0.0,
#  'phinn': 0.0,
#  'Eclipsed': 0.0,
#  'GoneFisching': 0.0,
#  'dadef': 0.0,
#  'morgi': 0.0,
#  'Garafurcizz': 0.0,
#  'imasoft': 0.0,
#  'lizi': 0.0,
#  'chezdude': 0.0,
#  'GrimAvenger': 0.0,
#  'Gooner': 0.0,
#  'welcome': 0.0,
#  'Moscardon': 0.0,
#  'aripal': 0.0,
#  'guys': 0.0,
#  'TATSUYAKING': 0.0,
#  'stickofchap': 0.0,
#  'SGP': 0.0,
#  'Panoramix': 0.0,
#  'GMK': 0.0,
#  'TEXX': 0.0,
#  'manamichan': 0.0,
#  'CyberDragon': 0.0,
#  'TheChuck': 0.0,
#  'cfp': 0.0,
#  'nemonick': 0.0,
#  'Ref': 0.0,
#  'HockeyGuy': 0.0,
#  'kurch': 0.0,
#  'koikoi': 0.0,
#  'nali': 0.0,
#  'Verymadman': 0.0,
#  'Dreisamtal': 0.0,
#  'fezzick': 0.0,
#  'Lautrec': 0.0,
#  'Concept': 0.0,
#  'Fleury': 0.0,
#  'MALNATH': 0.0,
#  'Framzowich': 0.0,
#  'nutnut': 0.0,
#  'czessmaster': 0.0,
#  'arthurharvey': 0.0,
#  'matis': 0.0,
#  'elfado': 0.0,
#  'mistajai': 0.0,
#  'chesscraft': 0.0,
#  'waldodrazic': 0.0,
#  'BuffAbcrunch': 0.0,
#  'chessprofessor': 0.0,
#  'LunarBard': 0.0,
#  'fradiavolo': 0.0,
#  'chungman': 0.0,
#  'moogz': 0.0,
#  'cds': 0.0,
#  'MikhailTal': 0.0,
#  'rezazock': 0.0,
#  'trv': 0.0,
#  'Gannon': 0.0,
#  'nmoses': 0.0,
#  'blankspace': 0.0,
#  'jamesbondss': 0.0,
#  'MySacha': 0.0,
#  'EddieHeim': 0.0,
#  'hgr': 0.0,
#  'gentor': 0.0,
#  'Zimbawee': 0.0,
#  'SiriusCC': 0.0,
#  'Basil': 0.0,
#  'ThinmanHwy': 0.0,
#  'WazR': 0.0,
#  'whales': 0.0,
#  'TiredKnight': 0.0,
#  'SuperPawns': 0.0,
#  'alexandrine': 0.0,
#  'WITTEL': 0.0,
#  'SexBomb': 0.0,
#  'Butcho': 0.0,
#  'Pomponazzi': 0.0,
#  'gags': 0.0,
#  'slowrider': 0.0,
#  'SmallPetronius': 0.0,
#  'trojanclone': 0.0,
#  'arammana': 0.0,
#  'Blucky': 0.0,
#  'gunar': 0.0,
#  'bgn': 0.0,
#  'Rosencratz': 0.0,
#  'rojooos': 0.0,
#  'tiana': 0.0,
#  'thornlea': 0.0,
#  'intermediate': 0.0,
#  'maxrus': 0.0,
#  'ckv': 0.0,
#  'Poetje': 0.0,
#  'bellarte': 0.0,
#  'BudapestGambit': 0.0,
#  'annamaria': 0.0,
#  'CHIGGERWORM': 0.0,
#  'BingPui': 0.0,
#  'mrw': 0.0,
#  'AcidSatyr': 0.0,
#  'TehnoMag': 0.0,
#  'cooba': 0.0,
#  'LCBone': 0.0,
#  'gdtn': 0.0,
#  'Nannan': 0.0,
#  'Lochess': 0.0,
#  'tonius': 0.0,
#  'psteele': 0.0,
#  'budfellow': 0.0,
#  'nohoper': 0.0,
#  'cphuhu': 0.0,
#  'Kihor': 0.0,
#  'ffkammer': 0.0,
#  'FerdzSupsup': 0.0,
#  'alexandgreg': 0.0,
#  'Prexxuss': 0.0,
#  'knoppe': 0.0,
#  'toune': 0.0,
#  'radr': 0.0,
#  'leoinflux': 0.0,
#  'Ginkgo': 0.0,
#  'petterpuss': 0.0,
#  'lallo': 0.0,
#  'AsKaS': 0.0,
#  'archnerd': 0.0,
#  'RVWCC': 0.0,
#  'malzmuehle': 0.0,
#  'uho': 0.0,
#  'Merrilin': 0.0,
#  'Stiller': 0.0,
#  'shookee': 0.0,
#  'sweettooth': 0.0,
#  'JPierre': 0.0,
#  'JORGECANO': 0.0,
#  'kame': 0.0,
#  'tiep': 0.0,
#  'ZenShark': 0.0,
#  'wlagen': 0.0,
#  'vinccrt': 0.0,
#  'Mazetov': 0.0,
#  'shacata': 0.0,
#  'AntonioZ': 0.0,
#  'AbusiveOrchid': 0.0,
#  'joegorham': 0.0,
#  'Belrond': 0.0,
#  'kuoppo': 0.0,
#  'soeryo': 0.0,
#  'freekbox': 0.0,
#  'LIMtoO': 0.0,
#  'Chevalaile': 0.0,
#  'Ricardoff': 0.0,
#  'siouxfour': 0.0,
#  'knighted': 0.0,
#  'Harmlessdutchie': 0.0,
#  'luvfordagame': 0.0,
#  'acknowledgement': 0.0,
#  'axelina': 0.0,
#  'Drusilla': 0.0,
#  'LadyCaper': 0.0,
#  'Sagitarius': 0.0,
#  'gcristescu': 0.0,
#  'adeptusmechanicus': 0.0,
#  'UnderTheMoon': 0.0,
#  'WildRook': 0.0,
#  'hollander': 0.0,
#  'DeepDude': 0.0,
#  'OPsilonautO': 0.0,
#  'DarkVendetta': 0.0,
#  'sinch': 0.0,
#  'Dannyza': 0.0,
#  'Notwinnik': 0.0,
#  'danrad': 0.0,
#  'Pablosb': 0.0,
#  'SSHHKK': 0.0,
#  'SeymourGlass': 0.0,
#  'samirkut': 0.0,
#  'jacquesk': 0.0,
#  'Synthor': 0.0,
#  'jhailito': 0.0,
#  'eban': 0.0,
#  'puchu': 0.0,
#  'pdiaz': 0.0,
#  'tomgogo': 0.0,
#  'mkgray': 0.0,
#  'Vinballe': 0.0,
#  'roeven': 0.0,
#  'HarryBooger': 0.0,
#  'cmpxchg': 0.0,
#  'CheeseChess': 0.0,
#  'rir': 0.0,
#  'matusx': 0.0,
#  'harebear': 0.0,
#  'lanceloth': 0.0,
#  'Schwede': 0.0,
#  'KNIGHTSPADE': 0.0,
#  'lsg': 0.0,
#  'laerion': 0.0,
#  'fagaras': 0.0,
#  'kdoolittle': 0.0,
#  'supercooky': 0.0,
#  'ovrebergvei': 0.0,
#  'wilykat': 0.0,
#  'AspILE': 0.0,
#  'Shipomatic': 0.0,
#  'sopiribo': 0.0,
#  'Rubinsteinitz': 0.0,
#  'BioVirus': 0.0,
#  'WindsOfThor': 0.0,
#  'Strifer': 0.0,
#  'dwnwrd': 0.0,
#  'Southerncomfort': 0.0,
#  'DaddyDealer': 0.0,
#  'espin': 0.0,
#  'augustiner': 0.0,
#  'Jaegermeister': 0.0,
#  'Molie': 0.0,
#  'cronjet': 0.0,
#  'woodya': 0.0,
#  'Sandburgchess': 0.0,
#  'skrivharr': 0.0,
#  'kecel': 0.0,
#  'Loic': 0.0,
#  'LexB': 0.0,
#  'AzmodanIX': 0.0,
#  'kingkings': 0.0,
#  'laserbond': 0.0,
#  'Philo': 0.0,
#  'prendav': 0.0,
#  'jwks': 0.0,
#  'ThomasHermansen': 0.0,
#  'tweetletwoot': 0.0,
#  'Cosinus': 0.0,
#  'sumdeo': 0.0,
#  'tmcmanamey': 0.0,
#  'BrownMagic': 0.0,
#  'BadIce': 0.0,
#  'ELMERJFUDD': 0.0,
#  'raksny': 0.0,
#  'omr': 0.0,
#  'defensemaster': 0.0,
#  'Cracle': 0.0,
#  'mdifonz': 0.0,
#  'Thymian': 0.0,
#  'mfried': 0.0,
#  'segwaba': 0.0,
#  'compost': 0.0,
#  'chrisindri': 0.0,
#  'Jarch': 0.0,
#  'createwaves': 0.0,
#  'maddy': 0.0,
#  'VegetaXX': 0.0,
#  'acwrn': 0.0,
#  'Hill': 0.0,
#  'hpissaia': 0.0,
#  'eCuthbert': 0.0,
#  'ErnestoCheGuevara': 0.0,
#  'TrumpCard': 0.0,
#  'Recike': 0.0,
#  'TimmyWitt': 0.0,
#  'coyotte': 0.0,
#  'boryha': 0.0,
#  'Onesinger': 0.0,
#  'XaveriusY': 0.0,
#  'arist': 0.0,
#  'ladydesiree': 0.0,
#  'CabinBoy': 0.0,
#  'gimelnus': 0.0,
#  'dimiter': 0.0,
#  'JohnnyV': 0.0,
#  'vjf': 0.0,
#  'barky': 0.0,
#  'CxJx': 0.0,
#  'wseidlich': 0.0,
#  'Bowf': 0.0,
#  'EnigmaG': 0.0,
#  'Lukaaa': 0.0,
#  'gromd': 0.0,
#  'Mpool': 0.0,
#  'hajsza': 0.0,
#  'Eho': 0.0,
#  'LMB': 0.0,
#  'carrett': 0.0,
#  'namyzarc': 0.0,
#  'chesscvo': 0.0,
#  'plaidavenger': 0.0,
#  'Robrob': 0.0,
#  'ElChico': 0.0,
#  'ashitakun': 0.0,
#  'kluc': 0.0,
#  'takitaro': 0.0,
#  'PiinTheFace': 0.0,
#  'lueo': 0.0,
#  'dogbull': 0.0,
#  'thiefmaster': 0.0,
#  'OneInSeven': 0.0,
#  'Chappe': 0.0,
#  'Delphinius': 0.0,
#  'camper': 0.0,
#  'nondescript': 0.0,
#  'gjerts': 0.0,
#  'Wespaman': 0.0,
#  'evits': 0.0,
#  'camaro': 0.0,
#  'grandmasterc': 0.0,
#  'EZZY': 0.0,
#  'IIII': 0.0,
#  'WiseTech': 0.0,
#  'bulbex': 0.0,
#  'barryth': 0.0,
#  'noglues': 0.0,
#  'zurginiev': 0.0,
#  'jotkas': 0.0,
#  'kalmannn': 0.0,
#  'Monokini': 0.0,
#  'thbech': 0.0,
#  'mutron': 0.0,
#  'chessprof': 0.0,
#  'ArturoBandini': 0.0,
#  'nerveless': 0.0,
#  'fidell': 0.0,
#  'kanizsa': 0.0,
#  'Macabros': 0.0,
#  'perplexpelle': 0.0,
#  'MowBjow': 0.0,
#  'AnneOfTheIsland': 0.0,
#  'Sixers': 0.0,
#  'Klim': 0.0,
#  'buzgub': 0.0,
#  'Sftownie': 0.0,
#  'IHWH': 0.0,
#  'Epictetus': 0.0,
#  'Fcuk': 0.0,
#  'xdoc': 0.0,
#  'rookking': 0.0,
#  'XTCHell': 0.0,
#  'ERLANK': 0.0,
#  'mouki': 0.0,
#  'tirarira': 0.0,
#  'BrainChild': 0.0,
#  'dannyhollingswort': 0.0,
#  'Tcchap': 0.0,
#  'ghattu': 0.0,
#  'GMWILLI': 0.0,
#  'Icebg': 0.0,
#  'ChessMuscle': 0.0,
#  'hebs': 0.0,
#  'UnsoundGambit': 0.0,
#  'theomen': 0.0,
#  'mavz': 0.0,
#  'vexore': 0.0,
#  'panzertp': 0.0,
#  'harttolove': 0.0,
#  'slickmickpc': 0.0,
#  'Ilari': 0.0,
#  'fuhrer': 0.0,
#  'WhiteFireCat': 0.0,
#  'hookahguy': 0.0,
#  'abccba': 0.0,
#  'Madmatts': 0.0,
#  'ldrop': 0.0,
#  'electric': 0.0,
#  'sveddi': 0.0,
#  'blavista': 0.0,
#  'Clarabelle': 0.0,
#  'Muhwag': 0.0,
#  'speedimonkey': 0.0,
#  'SaraEben': 0.0,
#  'BigDman': 0.0,
#  'elgizmo': 0.0,
#  'amxamx': 0.0,
#  'VonPeppe': 0.0,
#  'kraksmoka': 0.0,
#  'Clarett': 0.0,
#  'Pepitox': 0.0,
#  'suckysucky': 0.0,
#  'livtodamax': 0.0,
#  'TeamEek': 0.0,
#  'BabyGrl': 0.0,
#  'DrBoffin': 0.0,
#  'itr': 0.0,
#  'Highheels': 0.0,
#  'pijman': 0.0,
#  'velaganc': 0.0,
#  'induction': 0.0,
#  'Dumpy': 0.0,
#  'Schieber': 0.0,
#  'mrgodo': 0.0,
#  'zano': 0.0,
#  'jussukanion': 0.0,
#  'inconnu': 0.0,
#  'awe': 0.0,
#  'ScriptFu': 0.0,
#  'vaklo': 0.0,
#  'tikor': 0.0,
#  'lft': 0.0,
#  'sarkisov': 0.0,
#  'LongShanks': 0.0,
#  'Wega': 0.0,
#  'mskchess': 0.0,
#  'owski': 0.0,
#  'lateralus': 0.0,
#  'cruelman': 0.0,
#  'HarleyJ': 0.0,
#  'johnnyblade': 0.0,
#  'besil': 0.0,
#  'Graziani': 0.0,
#  'binny': 0.0,
#  'JackShadow': 0.0,
#  'Wladimirr': 0.0,
#  'ONKELTOM': 0.0,
#  'asana': 0.0,
#  'Nachtkatze': 0.0,
#  'aliceonacid': 0.0,
#  'provenself': 0.0,
#  'Koenigsmoerder': 0.0,
#  'niouge': 0.0,
#  'anahita': 0.0,
#  'NizzasIni': 0.0,
#  'larsodsather': 0.0,
#  'Patriarch': 0.0,
#  'EvilChess': 0.0,
#  'Moowuzz': 0.0,
#  'goelca': 0.0,
#  'Tappers': 0.0,
#  'fcatalin': 0.0,
#  'nostriluu': 0.0,
#  'postmanpat': 0.0,
#  'drefsab': 0.0,
#  'warrick': 0.0,
#  'festrilmongrit': 0.0,
#  'anty': 0.0,
#  'melkirwan': 0.0,
#  'Oliviermiaou': 0.0,
#  'enl': 0.0,
#  'hiddendragon': 0.0,
#  'Ganchessbis': 0.0,
#  'SaltyBalls': 0.0,
#  'fdsj': 0.0,
#  'coldbeer': 0.0,
#  'Gizmocat': 0.0,
#  'zakarum': 0.0,
#  'Flit': 0.0,
#  'Nigelbasil': 0.0,
#  'Positronicus': 0.0,
#  'Mafiosi': 0.0,
#  'JacobP': 0.0,
#  'Schwarti': 0.0,
#  'pikapika': 0.0,
#  'chessknutt': 0.0,
#  'Brimsgutten': 0.0,
#  'CocoBill': 0.0,
#  'vdrabek': 0.0,
#  'KingGabe': 0.0,
#  'roeckx': 0.0,
#  'EatYourKing': 0.0,
#  'pijavirtual': 0.0,
#  'bartholdi': 0.0,
#  'kalmus': 0.0,
#  'ShadowStalker': 0.0,
#  'vish': 0.0,
#  'LittleGary': 0.0,
#  'wookster': 0.0,
#  'FalkeBanker': 0.0,
#  'Warps': 0.0,
#  'SurfThru': 0.0,
#  'Schwab': 0.0,
#  'saylinda': 0.0,
#  'JVickery': 0.0,
#  'atabotix': 0.0,
#  'stagcerf': 0.0,
#  'ChessPanZ': 0.0,
#  'Gindu': 0.0,
#  'rmajoran': 0.0,
#  'ianball': 0.0,
#  'HAM': 0.0,
#  'kakaTa': 0.0,
#  'puspunk': 0.0,
#  'JustinSane': 0.0,
#  'Nimzovik': 0.0,
#  'SojournerTim': 0.0,
#  'zinChess': 0.0,
#  'MasterOfBishops': 0.0,
#  'marvline': 0.0,
#  'icewine': 0.0,
#  'drbauburn': 0.0,
#  'grandita': 0.0,
#  'argtango': 0.0,
#  'leavings': 0.0,
#  'gnappo': 0.0,
#  'chesshawk': 0.0,
#  'birnbaum': 0.0,
#  'BlackWolfS': 0.0,
#  'returnxero': 0.0,
#  'Houtbanner': 0.0,
#  'Willzilla': 0.0,
#  'Shambles': 0.0,
#  'FranciscoNicolas': 0.0,
#  'quoi': 0.0,
#  'rosemunn': 0.0,
#  'Illuvive': 0.0,
#  'whraven': 0.0,
#  'Stolz': 0.0,
#  'Radikalinski': 0.0,
#  'kimdonne': 0.0,
#  'Kadoc': 0.0,
#  'AvvGab': 0.0,
#  'cwillyg': 0.0,
#  'wakkanai': 0.0,
#  'brouhard': 0.0,
#  'WorldTraveller': 0.0,
#  'rituanil': 0.0,
#  'ogoret': 0.0,
#  'Zugriph': 0.0,
#  'Cusen': 0.0,
#  'burnzy': 0.0,
#  'jayati': 0.0,
#  'Vindicatorr': 0.0,
#  'steepid': 0.0,
#  'noren': 0.0,
#  'aintwonyet': 0.0,
#  'tetrakatus': 0.0,
#  'Runnner': 0.0,
#  'nuguy': 0.0,
#  'massimocrippa': 0.0,
#  'kevthai': 0.0,
#  'abrakadabra': 0.0,
#  'MCBlades': 0.0,
#  'lostrego': 0.0,
#  'bulldoggy': 0.0,
#  'ChessCracker': 0.0,
#  'oliv': 0.0,
#  'Jouzik': 0.0,
#  'Elle': 0.0,
#  'kaitenk': 0.0,
#  'SalDog': 0.0,
#  'aztechjoshk': 0.0,
#  'TheDarkSquare': 0.0,
#  'ebaneezer': 0.0,
#  'enroq': 0.0,
#  'cammo': 0.0,
#  'JimiJim': 0.0,
#  'Boogs': 0.0,
#  'giambo': 0.0,
#  'Yosh': 0.0,
#  'Eminence': 0.0,
#  'ksfromgreece': 0.0,
#  'Borba': 0.0,
#  'CrouchingAngel': 0.0,
#  'Darwinthegreat': 0.0,
#  'jtriumph': 0.0,
#  'Happyrook': 0.0,
#  'khanan': 0.0,
#  'Ttcashin': 0.0,
#  'UTRAreceiver': 0.0,
#  'Snoepy': 0.0,
#  ...}

# %%
_sorted = sorted(d, key=d.get, reverse=True)[:10]

h = ng.subgraph(_sorted)
nx.draw_circular(h, with_labels=True)

# %% [markdown]
# **Task 7:** Use Cytoscape to draw the Lord of the Rings Couples network (see Lecture 2).
# Fill the network's vertices in a different color according to the gender.
# Select each vertex shape to be according to the vertex race. (7pt)

# %%
# !mkdir /root/.kaggle/
import json
import os

# Installing the Kaggle package
# !pip install kaggle 

#Important Note: complete this with your own key - after running this for the first time remmember to **remove** your API_KEY
api_token = {"username":"aamitshakarchy","key":"004ade6e43f08b393cf10784d7e16ab0"}

# creating kaggle.json file with the personal API-Key details 
# You can also put this file on your Google Drive
with open('/root/.kaggle/kaggle.json', 'w') as file:
  json.dump(api_token, file)
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle/’: File exists
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
# !mkdir ./datasets/ltor

# download the dataset from Kaggle and unzip it
# !kaggle datasets download paultimothymooney/lord-of-the-rings-data  -p ./datasets/ltor
# !unzip ./datasets/ltor/*.zip  -d ./datasets/ltor
# !ls ./datasets/ltor
# Out:
# mkdir: cannot create directory ‘./datasets/ltor’: File exists
# Downloading lord-of-the-rings-data.zip to ./datasets/ltor
#   0% 0.00/88.0k [00:00<?, ?B/s]
# 100% 88.0k/88.0k [00:00<00:00, 40.6MB/s]
# Archive:  ./datasets/ltor/lord-of-the-rings-data.zip
#   inflating: ./datasets/ltor/lotr_characters.csv
#   inflating: ./datasets/ltor/lotr_scripts.csv
# lord-of-the-rings-data.zip  lotr_characters.csv  lotr_scripts.csv

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./datasets/ltor/lotr_characters.csv")
df = df.fillna('')
df
# Out:
#                                   birth  ...                                 spouse
# 0                                        ...                                Belemir
# 1                               TA 2978  ...
# 2                                        ...
# 3                                TA 280  ...                           Unnamed wife
# 4                                        ...
# ..                                  ...  ...                                    ...
# 906                      Mid ,First Age  ...                                 Brodda
# 907                                      ...
# 908  YT during the ,Noontide of Valinor  ...  Loved ,Andreth but remained unmarried
# 909                             TA 2917  ...                           Unnamed wife
# 910                     Before ,TA 1944  ...
#
# [911 rows x 9 columns]

# %%
import re
def normailze_spouse(s):
    if s in {'','Unnamed wife', 'None' }:
        return None
    if "Loved" not in s:
        return s
    
    r = re.compile("Loved ,(\w+)")
    l = r.findall(s)
    if len(l) > 0:
        return l[0]
df['normspouse'] = df['spouse'].apply(lambda s: normailze_spouse(s))
    
links_df = df[['name', 'normspouse', 'race', 'gender']]
links_df = links_df.dropna()
links_df
# Out:
#                   name    normspouse   race  gender
# 0               Adanel       Belemir    Men  Female
# 7               Angrod      Eldalótë  Elves    Male
# 10         Ar-Pharazôn    Tar-Míriel    Men    Male
# 12         Ar-Gimilzôr     Inzilbêth    Men    Male
# 21   Tarannon Falastur     Berúthiel    Men    Male
# ..                 ...           ...    ...     ...
# 897            Ailinel     Orchaldor    Men  Female
# 898           Almarian  Tar-Meneldur    Men  Female
# 899             Algund    None known    Men    Male
# 906              Aerin        Brodda    Men  Female
# 908             Aegnor       Andreth  Elves    Male
#
# [228 rows x 4 columns]

# %%
import networkx as nx

ng = nx.Graph()
ng = nx.from_pandas_edgelist(links_df, 'name', 'normspouse')

for n in ng:
  race_list = list(links_df[links_df['name'] == str(n)]['race'])
  gender_list = list(links_df[links_df['name'] == str(n)]['gender'])
  if len(race_list) > 0:
    ng.nodes[n]['race'] = race_list[0]
  else: 
     ng.nodes[n]['race'] = "Unknown"
  if len(gender_list) > 0:
    ng.nodes[n]['gender'] = gender_list[0]
  else: 
     ng.nodes[n]['gender'] = "Unknown"

ng.nodes(data = True)
#print(nx.info(ng))
nx.write_gml(ng, "lord_of_rings.gml")

# %%
#  Use Cytoscape to draw the Lord of the Rings Couples network (see Lecture 2). Fill the network's vertices in a different color according to the gender. 
# Select each vertex shape to be according to the vertex race. (7pt)

# %% [markdown]
# ![lord_of_rings.gml.png](data:image/png;base64,...)

# %% [markdown]
# ### Additional Questions for Practice

# %% [markdown]
# **Task 1:** Visualize the distribution of the network's strongly and weakly connected components.

# %% [markdown]
# **Task 2:** Using Cytoscape, visualize the network's maximal strongly connected component (or part of it)

# %% [markdown]
# **Task 3:** Draw a subgraph of all the vertices that have at least one reciprocal link, i.e., all the vertices where there is at least one vertex _u_ so that both links (u,v) and (v,u) exists

# %% [markdown]
# **Task 4:** Split the network into communities, and find the second most central vertex in each community

# %% [markdown]
# **Task 5:** Find the top-10 most central players at [The Free Internet Chess Server](http://dynamics.cs.washington.edu/nobackup/chess/fcis.tar.gz).
#     Visualize part of the network.
#
# **Note:** The network has 429,747,476 edges
